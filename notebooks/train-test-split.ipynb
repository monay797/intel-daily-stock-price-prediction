# %%
import pandas as pd
import joblib

# %%
df = pd.read_csv(
    r"C:\Users\norie\Documents\Machine Learning\Projects\intel-daily-stock-price-prediction\data\processed\intel-daily-stock-price-data-processed.csv",
    index_col="Date",
    parse_dates=True
                )
df.head()
# Out:
#                 Close        MA5       MA14  Daily Return        RSI  \
# Date
# 2021-04-29  53.006393  53.091891  56.458647      0.011454  16.644387
# 2021-04-30  52.324265  52.780837  55.946722     -0.012869  19.362367
# 2021-05-03  52.078697  52.507984  55.429599     -0.004693  19.242655
# 2021-05-04  51.751266  52.313348  54.956002     -0.006287  20.293397
# 2021-05-05  51.705795  52.173283  54.425237     -0.000879  14.447361
#
#             Bollinger Band Width  High-Low Range  Relative Volume    Target
# Date
# 2021-04-29              0.206127        0.754894         0.746251 -0.012869
# 2021-04-30              0.222169        1.236938         0.985754 -0.004693
# 2021-05-03              0.231542        0.945894         0.721263 -0.006287
# 2021-05-04              0.241925        1.064128         1.131433 -0.000879
# 2021-05-05              0.246577        0.763991         0.669262  0.012176

# %%
X = df.drop("Target", axis=1)
y = df["Target"]

# %%
split_data = int(len(X) * 0.8)

X_train, y_train = X.iloc[:split_data], y.iloc[:split_data]
X_test, y_test = X.iloc[split_data:], y.iloc[split_data:]

# %%
joblib.dump([X_train, y_train, X_test, y_test], r"C:\Users\norie\Documents\Machine Learning\Projects\intel-daily-stock-price-prediction\notebooks\train-test-split.joblib")
# Out:
# ['C:\\Users\\norie\\Documents\\Machine Learning\\Projects\\intel-daily-stock-price-prediction\\notebooks\\train-test-split.joblib']
