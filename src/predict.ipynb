# %%
import pandas as pd
import joblib

# Load Data
X_test = pd.read_csv(
    r"C:\Users\norie\Documents\Machine Learning\Projects\intel-daily-stock-price-prediction\data\processed\X_test.csv",
    index_col="Date",
    parse_dates=True
)

# Load Model
model = joblib.load(r"C:\Users\norie\Documents\Machine Learning\Projects\intel-daily-stock-price-prediction\models\linear_regression_v1.pkl")

pred = model.predict(X_test)

# %%
single_input = pd.DataFrame([{
    "Open": 123.85,
    "High": 126.64,
    "Low": 113.54,
    "Close": 114.68,
    "MA5": 120.14,
    "MA14": 118.01,
    "High-Low Range": 13.10
}])

pred = model.predict(single_input)
print(pred)
# Out:
# [116.72839958]
